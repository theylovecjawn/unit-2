# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
# This file contains the different area codes for the different states repeatedly.
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
read = open("states.txt", "r") #sets the object to this variable
for i in read: #for statement to print all the different things in the object 
    print(i) #prints the inputs
# Out:
# WA
#
# MO
#
# KS
#
# SC
#
# GA
#
# FL
#
# MN
#
# NC
#
# HI
#
# CT
#
# TX
#
# MA
#
# OK
#
# IL
#
# HI
#
# CA
#
# TX
#
# WA
#
# OH
#
# PA
#
# MO
#
# IL
#
# CA
#
# IL
#
# CA
#
# DC
#
# FL
#
# NC
#
# NY
#
# VA
#
# TX
#
# CA
#
# DC
#
# TX
#
# OH
#
# WA
#
# FL
#
# MN
#
# DC
#
# FL
#
# CA
#
# FL
#
# TX
#
# CT
#
# NC
#
# MO
#
# TX
#
# MA
#
# TX
#
# WA
#
# IN
#
# IN
#
# MO
#
# AL
#
# OK
#
# GA
#
# NY
#
# IN
#
# OK
#
# IN
#
# CA
#
# GA
#
# CA
#
# CA
#
# IN
#
# NY
#
# MS
#
# CA
#
# NV
#
# ID
#
# MN
#
# VA
#
# WY
#
# WV
#
# MN
#
# MO
#
# TX
#
# MA
#
# IN
#
# IA
#
# WA
#
# MN
#
# CA
#
# NE
#
# IL
#
# IL
#
# PA
#
# GA
#
# TX
#
# OH
#
# DE
#
# TX
#
# NM
#
# TX
#
# MA
#
# LA
#
# GA
#
# TN
#
# CA
#
# DC
#
# FL
#
# CO
#
# MI
#
# MD
#
# FL
#
# FL
#
# NC
#
# OH
#
# IA
#
# NE
#
# TX
#
# IN
#
# TX
#
# CA
#
# TX
#
# IL
#
# CA
#
# VA
#
# TX
#
# CA
#
# NY
#
# IN
#
# NY
#
# OH
#
# NY
#
# TN
#
# DC
#
# CA
#
# MN
#
# VA
#
# UT
#
# NH
#
# TX
#
# CA
#
# PA
#
# CO
#
# TX
#
# FL
#
# CA
#
# PA
#
# OH
#
# MD
#
# CT
# ...

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
# A bar graph would be best for this because of the repeated amounts of states.
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
# To transform the data we would have to import mathplotlibs and then use the "r" to view and access the information within the file. Then use that data and the with function create the graph.
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
import matplotlib.pyplot as plt

f = open('states.txt', 'r') #opens the states.txt and allows us to read it 
#sets the state code value to 0 before the for loop
NY = 0
FL = 0
MO = 0
TX = 0
KS = 0
CA = 0
IL = 0
PA = 0
AZ = 0
AL = 0
AK = 0
AR = 0
CO = 0
CT = 0
DE = 0
GA = 0
HI = 0
ID = 0
IN = 0
IA = 0
KY = 0
LA = 0
ME = 0
MD = 0
MA = 0
MI = 0
MN = 0
MS = 0
MT = 0
NE = 0
NV = 0
NH = 0
NJ = 0
NM = 0
NC = 0
ND = 0
OH = 0
OK = 0
OR = 0
RI = 0
SC = 0
SD = 0
TN = 0
UT = 0
VT = 0
VA = 0
WA = 0
WV = 0
WI = 0
WY = 0

for row in f: #for loop that adds 1 when ever the codes are found in each line of the states.txt
    row = row.strip()
    if row == "NY":
        NY += 1
    elif row == "MO":
        MO += 1
    elif row == "FL":
        FL += 1
    elif row == "TX":
        TX += 1
    elif row == "KS":
        KS += 1
    elif row == "CA":
        CA += 1
    elif row == "IL":
        IL += 1
    elif row == "PA":
        PA += 1
    elif row == "AZ":
        AZ += 1
    elif row == "AL":
        AL += 1
    elif row == "AK":
        AK += 1
    elif row == "AR":
        AR += 1
    elif row == "CO":
        CO += 1
    elif row == "CT":
        CT += 1
    elif row == "DE":
        DE += 1
    elif row == "GA":
        GA += 1
    elif row == "HI":
        HI += 1
    elif row == "ID":
        ID += 1
    elif row == "IN":
        IN += 1
    elif row == "IA":
        IA += 1
    elif row == "KY":
        KY += 1
    elif row == "LA":
        LA += 1
    elif row == "ME":
        ME += 1
    elif row == "MD":
        MD += 1
    elif row == "MA":
        MA += 1
    elif row == "MI":
        MI += 1
    elif row == "MN":
        MN += 1
    elif row == "MS":
        MS += 1
    elif row == "MT":
        MT += 1
    elif row == "NE":
        NE += 1
    elif row == "NV":
        NV += 1
    elif row == "NH":
        NH += 1
    elif row == "NJ":
        NJ += 1
    elif row == "NM":
        NM += 1
    elif row == "NC":
        NC += 1
    elif row == "ND":
        ND += 1
    elif row == "OH":
        OH += 1
    elif row == "OK":
        OK += 1
    elif row == "OR":
        OR += 1
    elif row == "RI":
        RI += 1
    elif row == "SC":
        SC += 1
    elif row == "SD":
        SD += 1
    elif row == "TN":
        TN += 1
    elif row == "UT":
        UT += 1
    elif row == "VT":
        VT += 1
    elif row == "VA":
        VA += 1
    elif row == "WA":
        WA += 1
    elif row == "WV":
        WV += 1
    elif row == "WI":
        WI += 1
    elif row == "WY":
        WY += 1

state_names = ["NY", "FL", "MO", "TX", "KS", "CA", "IL", "PA", "AZ", "AL", "AK", "AR", "CO", "CT", "DE", "GA", "HI", "ID", "IN", "IA", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MT", "NE", "NV", "NH", "NJ", "NM", "NC", "ND", "OH", "OK", "OR", "RI", "SC", "SD", "TN", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
#puts all the codes in a list 
state_counts = [NY, FL, MO, TX, KS, CA, IL, PA, AZ, AL, AK, AR, CO, CT, DE, GA, HI, ID, IN, IA, KY, LA, ME, MD, MA, MI, MN, MS, MT, NE, NV, NH, NJ, NM, NC, ND, OH, OK, OR, RI, SC, SD, TN, UT, VT, VA, WA, WV, WI, WY]
#puts the counts of the codes in a list
plt.figure(figsize=(12, 6))  # adjusts the figure size
plt.bar(state_names, state_counts, color='g', label='States Data') #creates the bar and adds the x,y axis and changed the color and label
plt.xlabel('State Names', fontsize=12) # labels the name of the x "State Names"
plt.ylabel('Amount', fontsize=12)# labels the name of the x "State Names"
plt.title('State Amount', fontsize=20) # the title is created
plt.xticks(rotation=70)  # rotates the x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=.5)  # add a grid for the y-axis
plt.legend() #creates the bar graoh legend

# %% [markdown]
# ## Explanation of the work
#
# So after observing this graph I see that with all the 50 states being shown CA is the most repeated within the states.txt file, The second runner up is TX. There are a bunch of state codes that have been repeated many times, and some only one time.
